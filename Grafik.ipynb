# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.bar(["2021"],[344.7],color='green',alpha=0.5)
plt.bar(["2022"],[314.1],color='blue',alpha=0.5)

plt.grid(linestyle='--',linewidth=2,axis='y',alpha=0.5)

plt.xlabel("Tahun Penjualan")
plt.ylabel("Total Penjualan (Juta unit)")
plt.title("Penjualan Handphone Tahun 2021 dan 2022")

plt.show()
plt.savefig("grafik penjualan.png")
